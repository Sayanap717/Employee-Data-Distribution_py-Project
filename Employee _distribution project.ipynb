# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\USER\Desktop\Python_ds\myexcel - myexcel.csv.csv")

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Height"]
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %% [markdown]
# ### replacing height with random number between 150 and 180

# %%
df["Height"]=[random.randint(150,180) for _ in range(len(df))]

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %% [markdown]
# ## 👆 College and Salary columns have null values

# %%
df.duplicated().sum()  #total count of duplcates is 0 for entire rows
# Out:
# 0

# %%
df.isnull()  # check the null values
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %%
df.isnull().sum()  #total count of null values for entire row
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ## 👆 College and Salary columns contain 84 and 11 null values

# %%
df.isnull().mean()
# Out:
# Name        0.000000
# Team        0.000000
# Number      0.000000
# Position    0.000000
# Age         0.000000
# Height      0.000000
# Weight      0.000000
# College     0.183406
# Salary      0.024017
# dtype: float64

# %%
df.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  165.255459  221.543668  4.833970e+06
# std     15.966837    4.400128    8.977130   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  158.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  166.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %% [markdown]
# ## 👆 findng the mean of Salary column to replace null values

# %%
value=str('4.833970e+06')
value2=value.replace(',', '.')
float(value2)
# Out:
# 4833970.0

# %% [markdown]
#  #### replaced with the meanvalue of salary

# %%
df["Salary"]=df["Salary"].fillna("4833970.0")

# %%
df["Salary"]
# Out:
# 0      7730337.0
# 1      6796117.0
# 2      4833970.0
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457     947276.0
# Name: Salary, Length: 458, dtype: object

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %% [markdown]
# ## ✅ salary null values are removed

# %%
df["College"].count()
# Out:
# 374

# %%
df.groupby("College").count()
# Out:
#                   Name  Team  Number  Position  Age  Height  Weight  Salary
# College
# Alabama              3     3       3         3    3       3       3       3
# Arizona             13    13      13        13   13      13      13      13
# Arizona State        2     2       2         2    2       2       2       2
# Arkansas             3     3       3         3    3       3       3       3
# Baylor               1     1       1         1    1       1       1       1
# ...                ...   ...     ...       ...  ...     ...     ...     ...
# Western Michigan     1     1       1         1    1       1       1       1
# Wichita State        1     1       1         1    1       1       1       1
# Wisconsin            5     5       5         5    5       5       5       5
# Wyoming              1     1       1         1    1       1       1       1
# Xavier               1     1       1         1    1       1       1       1
#
# [118 rows x 8 columns]

# %% [markdown]
# ## 👆 find out the college having most values for replace with null values

# %% [markdown]
# ##### replaced with arizona which is having most values

# %%
df["College"]=df["College"].fillna("Arizona")

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# ✅ Removed all null values

# %% [markdown]
# #### 👇 Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees

# %%
df_count=df["Team"].value_counts()
df_count
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# ### 👉 distrbuton of employees in each team

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 32.3+ KB

# %%
df_percentage= (df_count/len(df))*100
df_percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %% [markdown]
#  #### 👇Barplot represents the number of employess in each team and the percentage split relative to the total number of employees

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df_percentage.index,y=df_percentage.values, palette='light:#5A9',)
plt.xlabel("Team Name",fontsize=15)           #xlabel
plt.ylabel("Employee Count",fontsize=15)      #ylabel
plt.xticks(rotation=90)                       #vertical printing of x axis
plt.title("Distribution of Employees across each Team",fontsize=25)
for i,percentage in enumerate(df_percentage):
    plt.text(i, percentage + 0.1, f'{df_percentage[i]:.2f}%', ha='center', va='top')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8092\2170936763.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_percentage.index,y=df_percentage.values, palette='light:#5A9',)
# C:\Users\USER\AppData\Local\Temp\ipykernel_8092\2170936763.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(i, percentage + 0.1, f'{df_percentage[i]:.2f}%', ha='center', va='top')

# %% [markdown]
# ### 👇 Segregate employees based on their positions within the company

# %%
df_position= df["Position"].value_counts()
df_position
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# #### 👇 Piechart represents the distribution of employees by Postion

# %%
plt.pie(df_position,labels=df_position.index,autopct='%1.1f%%',radius=1.2,colors=['#F7ECD7','#DDAC57','#A1BAC2', '#D8B4ED', '#D3DFCB'])
plt.title('Employee Distribution by Position',fontsize = 10,fontweight= 'bold')
plt.show()

# %% [markdown]
# #### 👇 Identify the predominant age group among employees.

# %%
df_preage= df["Age"].value_counts()
df_preage
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
bins = [18, 24, 34, 44, 54, 65]
labels = ['18-24', '25-34', '35-44', '45-54', '55-65']
df["Age Group"] = pd.cut(df["Age"], bins=bins, labels=labels, right=False)  # Categorize the ages into age groups
df["Age Group"]
# Out:
# 0      25-34
# 1      25-34
# 2      25-34
# 3      18-24
# 4      25-34
#        ...
# 453    25-34
# 454    25-34
# 455    25-34
# 456    25-34
# 457    25-34
# Name: Age Group, Length: 458, dtype: category
# Categories (5, object): ['18-24' < '25-34' < '35-44' < '45-54' < '55-65']

# %%
predominant_agegroup = df["Age Group"].value_counts()    #Find the predominant age group
print(predominant_agegroup)
# Out:
# Age Group
# 25-34    309
# 18-24    107
# 35-44     42
# 45-54      0
# 55-65      0
# Name: count, dtype: int64

# %% [markdown]
# ✅ The predominant age group range is 25-34

# %%
plt.figure(figsize=(10,5))
plt.plot(predominant_agegroup.index,predominant_agegroup.values,marker='o',linestyle='dotted',color='blue',markersize=10)
plt.title('Employee Distribution by Age Group',fontweight='bold',fontsize=12,color='orange')
plt.xlabel("Age Group",fontsize=10)           #xlabel
plt.ylabel("Count of Employees",fontsize=10)      #ylabel
plt.show()

# %% [markdown]
# #### 👆 Line graph represents the distribution of employees by Age group

# %% [markdown]
# #### Discover which team and position have the highest salary expenditure.

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary Age Group
# 0                Texas  7730337.0     25-34
# ...

# %%
df["Salary"].max()
# Out:
# 25000000.0

# %%
df["Salary"] = pd.to_numeric(df["Salary"], errors='coerce') # convert to numeric value

# %%
df[df["Salary"]==df["Salary"].max()]
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37     173     212
#
#      College      Salary Age Group
# 109  Arizona  25000000.0     35-44

# %%
salary_expenditure = df.groupby(['Team', 'Position'])['Salary'].sum().unstack()
salary_expenditure

# %%
salary_expenditure.plot(kind='bar',figsize=(15,8), stacked=True)
plt.title('Salary Expenditure by Position and Team',fontweight ='bold',fontsize = 15)
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.xticks(rotation=90)
plt.show()

# %%
correlation_matrix = df[['Age', 'Salary']].corr()
correlation_matrix
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %% [markdown]
# ## 👆 Correlation between Age and Salary

# %%
plt.figure(figsize=(6,6))
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu', center=0)
plt.title('Correlation Heatmap Between Age and Salary')
plt.show()

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary Age Group
# 0                Texas  7730337.0     25-34
# ...

# %%
df.drop("Age Group",axis=1,inplace=True) #to remove an extra column Age Group

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     175     256
# 456    Jeff Withey       Utah Jazz      24        C   26     160     231
# 457       Priyanka       Utah Jazz      34        C   25     152     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.to_csv("Cleaned Data.csv",index=False)  # Final Cleaned Data as csv file
